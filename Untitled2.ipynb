# %% [markdown]
# # べっぴーさん就活の巻

# %%
A="みつじゅー"
B="トヨタ中堅"
D = "インスパイアザネクスト"

# %%
C = [A, B, D]

# %%
import random

random.seed()

r=  random.random()

if r<0.33:
    i = 0
elif 0.33<=r<0.66:
    i = 1
else:
    i = 2

print(C[i])
# Out:
# インスパイアザネクスト
