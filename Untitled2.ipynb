# %% [markdown]
# # べっぴーさん就活の巻

# %%
A="みつじゅー"
B="Toyota Central R&D Laboratory"
C="Academia"
D="himo"

# %%
choice = [A, B, C, D]

# %%
import random

random.seed()

r=  random.random()


if r<0.0:
    i = 0
elif r<0.3:
    i = 2
else:
    i = 3

print(choice[i])
# Out:
# himo
